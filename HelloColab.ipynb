# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LEE-Sanghoon/ITE4052/blob/main/HelloColab.ipynb)

# %%
print("Hello, Colab")
# Out:
# Hello, Colab

# %%
! ls -al
# Out:
# total 16
# drwxr-xr-x@  5 baramice  staff  160 Apr 16 02:24 .
# drwxr-xr-x  13 baramice  staff  416 Apr 16 02:06 ..
# drwxr-xr-x@ 15 baramice  staff  480 Apr 16 02:28 .git
# -rw-r--r--@  1 baramice  staff  711 Apr 16 02:29 HelloColab.ipynb
# -rw-r--r--@  1 baramice  staff   10 Apr 16 02:06 README.md

# %%
# !pip3 install ColabTurtle
form ColabTurtle import Turtle as t

t.initializeTurtle()
t.shape("turtle")

t.forward(100)
t.left(90)
t.forward(100)

# %%
import cv2
cv2.__version__

# %%
from google.colab import files
uploaded = files.upload()

# %%
img = cv2.imread('lena.png', cv2.IMAGE_COLOR)

from google.colab.patches import cv2_imshow
cv2_imshow(img)
